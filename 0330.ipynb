# %% [markdown]
# <a href="https://colab.research.google.com/github/hanhan0220/Introduction-to-Computers/blob/main/0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hi')
# Out:
# Hi

# %%
not(3>5)
# Out:
# True

# %% [markdown]
# ![吃未命名.png](data:image/png;base64,...)

# %%
not(5>3)
# Out:
# False

# %%
(5>3)and((9>6))
# Out:
# True

# %%
(5>3)and(9<6)
# Out:
# False

# %%
(5<3)and(9>6)
# Out:
# False

# %%
(5<3)and(9<6)
# Out:
# False

# %%
(5>3)or(9>6)
# Out:
# True

# %%
(5>3)or(9<6)
# Out:
# True

# %%
(5<3)or(9>6)
# Out:
# True

# %%
(5<3)or(9<6)
# Out:
# False

# %%
A=1

# %%
i=10

# %%
i+=5

# %%
i
# Out:
# 15

# %%
i-=5
i
# Out:
# 10

# %%
i=10

# %%
i-=5
i
# Out:
# 5

# %%
i=10
i*=5
i
# Out:
# 50

# %%
print(1+2)
# Out:
# 3

# %%
print('1'+'2')
# Out:
# 12

# %%
print('你'+'好'+'!')
# Out:
# 你好!

# %%
deposit=int(input('請輸入本金存款金額:'))
years=1.02**6
deposit*=years
print('6年後存款為:'+str(deposit))
# Out:
# 請輸入本金存款金額:10000
# 6年後存款為:11261.62419264

# %%
pw=input('請輸入密碼')
if(pw=='1234'):
 print('歡迎光臨!')
# Out:
# 請輸入密碼1234
# 歡迎光臨!

# %%
rain=input("今天會下雨嗎?")
if(rain=='Y'or rain=='y'):
 print('出門記得帶傘!')
# Out:
# 今天會下雨嗎?y
# 出門記得帶傘!

# %%
a=int(input('請輸入一個正整數:'))
if a%2==0:
  print("是偶數")
else:
  print("是基數")
# Out:
# 請輸入一個正整數:3
# 是基數
